# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('Automobile_data.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df["symboling"].value_counts()
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64

# %%
for columns in df.columns:
    print(df[columns].value_counts())
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: count, dtype: int64
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# ...

# %%
df.replace("?",np.nan,inplace=True)

# %%
for columns in df.columns:
    print(df[columns].value_counts())
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64
# normalized-losses
# 161    11
# 91      8
# 150     7
# 128     6
# 134     6
# 104     6
# 95      5
# 102     5
# 103     5
# 74      5
# 85      5
# 168     5
# 94      5
# 65      5
# 106     4
# 122     4
# 148     4
# 118     4
# 93      4
# 101     3
# 125     3
# 137     3
# 154     3
# 83      3
# 115     3
# 119     2
# 87      2
# 194     2
# 197     2
# 108     2
# 89      2
# 164     2
# 158     2
# 145     2
# 192     2
# 188     2
# 81      2
# 110     2
# 113     2
# 129     2
# 153     2
# 107     1
# 78      1
# 186     1
# 231     1
# 77      1
# 98      1
# 121     1
# 90      1
# 142     1
# 256     1
# Name: count, dtype: int64
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# ...

# %%
df.replace("peugot","peugeot",inplace=True)

# %%
df.replace("alfa-romero","alfa-romeo",inplace=True)

# %%
for columns in df.columns:
    print(df[columns].value_counts())
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64
# normalized-losses
# 161    11
# 91      8
# 150     7
# 128     6
# 134     6
# 104     6
# 95      5
# 102     5
# 103     5
# 74      5
# 85      5
# 168     5
# 94      5
# 65      5
# 106     4
# 122     4
# 148     4
# 118     4
# 93      4
# 101     3
# 125     3
# 137     3
# 154     3
# 83      3
# 115     3
# 119     2
# 87      2
# 194     2
# 197     2
# 108     2
# 89      2
# 164     2
# 158     2
# 145     2
# 192     2
# 188     2
# 81      2
# 110     2
# 113     2
# 129     2
# 153     2
# 107     1
# 78      1
# 186     1
# 231     1
# 77      1
# 98      1
# 121     1
# 90      1
# 142     1
# 256     1
# Name: count, dtype: int64
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugeot          11
# volvo            11
# dodge             9
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.head()
# Out:
#    symboling normalized-losses        make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romeo       gas        std          two
# 1          3               NaN  alfa-romeo       gas        std          two
# 2          1               NaN  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df['normalized-losses'] = df['normalized-losses'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['bore'] = df['bore'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['stroke'] = df['stroke'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['horsepower'] = df['horsepower'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['peak-rpm'] = df['peak-rpm'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['price'] = df['price'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
num_col=['normalized-losses','bore','stroke','horsepower','peak-rpm']
for i in num_col:
    df[i]=df[i].fillna(df[i].mean())

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df['num-of-doors']=df['num-of-doors'].fillna(df['num-of-doors'].mode()[0])

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.dropna(subset=['price'],inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 0            3              122.0  alfa-romeo       gas        std
# 1            3              122.0  alfa-romeo       gas        std
# 2            1              122.0  alfa-romeo       gas        std
# 3            2              164.0        audi       gas        std
# 4            2              164.0        audi       gas        std
# ..         ...                ...         ...       ...        ...
# 196         -1               95.0       volvo       gas        std
# 197         -1               95.0       volvo       gas      turbo
# 198         -1               95.0       volvo       gas        std
# 199         -1               95.0       volvo    diesel      turbo
# 200         -1               95.0       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ### EDA

# %% [markdown]
# Univariate for numerical

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["normalized-losses"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['normalized-losses'].describe())
# Out:
# count    201.00000
# mean     122.00000
# std       31.99625
# min       65.00000
# 25%      101.00000
# 50%      122.00000
# 75%      137.00000
# max      256.00000
# Name: normalized-losses, dtype: float64

# %%
sns.kdeplot(df["normalized-losses"], shade=True)
plt.title("KDE Plot of normalized-losses")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\3991603709.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["normalized-losses"], shade=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["wheel-base"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['wheel-base'].describe())
# Out:
# count    201.000000
# mean      98.797015
# std        6.066366
# min       86.600000
# 25%       94.500000
# 50%       97.000000
# 75%      102.400000
# max      120.900000
# Name: wheel-base, dtype: float64

# %%
sns.kdeplot(df["wheel-base"], shade=True)
plt.title("KDE Plot of wheel-base")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\1663565405.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["wheel-base"], shade=True)

# %%
sns.stripplot(y=df["wheel-base"], jitter=True)
plt.title("Strip Plot of wheel-base")
plt.show()

# %%
sns.histplot(df["length"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['length'].describe())
sns.kdeplot(df["length"], shade=True)
plt.title("KDE Plot of length")
plt.show()
# Out:
# count    201.000000
# mean     174.200995
# std       12.322175
# min      141.100000
# 25%      166.800000
# 50%      173.200000
# 75%      183.500000
# max      208.100000
# Name: length, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\3872697482.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["length"], shade=True)

# %%
sns.histplot(df["width"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['width'].describe())
sns.kdeplot(df["width"], shade=True)
plt.title("KDE Plot of width")
plt.show()
# Out:
# count    201.000000
# mean      65.889055
# std        2.101471
# min       60.300000
# 25%       64.100000
# 50%       65.500000
# 75%       66.600000
# max       72.000000
# Name: width, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\4225011030.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["width"], shade=True)

# %%
sns.histplot(df["height"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['height'].describe())
sns.kdeplot(df["height"], shade=True)
plt.title("KDE Plot of height")
plt.show()
# Out:
# count    201.000000
# mean      53.766667
# std        2.447822
# min       47.800000
# 25%       52.000000
# 50%       54.100000
# 75%       55.500000
# max       59.800000
# Name: height, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\1483729822.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["height"], shade=True)

# %%
sns.histplot(df["curb-weight"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['curb-weight'].describe())
sns.kdeplot(df["curb-weight"], shade=True)
plt.title("KDE Plot of curb-weight")
plt.show()
# Out:
# count     201.000000
# mean     2555.666667
# std       517.296727
# min      1488.000000
# 25%      2169.000000
# 50%      2414.000000
# 75%      2926.000000
# max      4066.000000
# Name: curb-weight, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\3798978924.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["curb-weight"], shade=True)

# %%
sns.histplot(df["curb-weight"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['curb-weight'].describe())
sns.kdeplot(df["curb-weight"], shade=True)
plt.title("KDE Plot of curb-weight")
plt.show()
# Out:
# count     201.000000
# mean     2555.666667
# std       517.296727
# min      1488.000000
# 25%      2169.000000
# 50%      2414.000000
# 75%      2926.000000
# max      4066.000000
# Name: curb-weight, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\3798978924.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["curb-weight"], shade=True)

# %%
sns.histplot(df["engine-size"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['curb-weight'].describe())
sns.kdeplot(df["engine-size"], shade=True)
plt.title("KDE Plot of engine-size")
plt.show()
# Out:
# count     201.000000
# mean     2555.666667
# std       517.296727
# min      1488.000000
# 25%      2169.000000
# 50%      2414.000000
# 75%      2926.000000
# max      4066.000000
# Name: curb-weight, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\2944857088.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["engine-size"], shade=True)

# %%
sns.histplot(df["bore"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['bore'].describe())
sns.kdeplot(df["bore"], shade=True)
plt.title("KDE Plot of bore")
plt.show()
# Out:
# count    201.000000
# mean       3.330692
# std        0.268072
# min        2.540000
# 25%        3.150000
# 50%        3.310000
# 75%        3.580000
# max        3.940000
# Name: bore, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\921329752.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["bore"], shade=True)

# %%
sns.histplot(df["stroke"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['stroke'].describe())
sns.kdeplot(df["stroke"], shade=True)
plt.title("KDE Plot of stroke")
plt.show()
# Out:
# count    201.000000
# mean       3.256874
# std        0.316048
# min        2.070000
# 25%        3.110000
# 50%        3.290000
# 75%        3.410000
# max        4.170000
# Name: stroke, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\87360731.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["stroke"], shade=True)

# %%
sns.histplot(df["compression-ratio"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['compression-ratio'].describe())
sns.kdeplot(df["compression-ratio"], shade=True)
plt.title("KDE Plot of compression-ratio")
plt.show()
# Out:
# count    201.000000
# mean      10.164279
# std        4.004965
# min        7.000000
# 25%        8.600000
# 50%        9.000000
# 75%        9.400000
# max       23.000000
# Name: compression-ratio, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\1495514218.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["compression-ratio"], shade=True)

# %%
sns.histplot(df["horsepower"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['horsepower'].describe())
sns.kdeplot(df["horsepower"], shade=True)
plt.title("KDE Plot of horsepower")
plt.show()
# Out:
# count    201.000000
# mean     103.405534
# std       37.365700
# min       48.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      262.000000
# Name: horsepower, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\2190948263.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["horsepower"], shade=True)

# %%
sns.histplot(df["peak-rpm"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['peak-rpm'].describe())
sns.kdeplot(df["peak-rpm"], shade=True)
plt.title("KDE Plot of peak-rpm")
plt.show()
# Out:
# count     201.000000
# mean     5117.665368
# std       478.113805
# min      4150.000000
# 25%      4800.000000
# 50%      5125.369458
# 75%      5500.000000
# max      6600.000000
# Name: peak-rpm, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\427932602.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["peak-rpm"], shade=True)

# %%
sns.histplot(df["city-mpg"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['city-mpg'].describe())
sns.kdeplot(df["city-mpg"], shade=True)
plt.title("KDE Plot of city-mpg")
plt.show()
# Out:
# count    201.000000
# mean      25.179104
# std        6.423220
# min       13.000000
# 25%       19.000000
# 50%       24.000000
# 75%       30.000000
# max       49.000000
# Name: city-mpg, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_19740\2796016222.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["city-mpg"], shade=True)

# %%
sns.histplot(df["highway-mpg"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['highway-mpg'].describe())
sns.kdeplot(df["highway-mpg"], shade=True)
plt.title("KDE Plot of highway-mpg")
plt.show()
# Out:
# count    201.000000
# mean      30.686567
# std        6.815150
# min       16.000000
# 25%       25.000000
# 50%       30.000000
# 75%       34.000000
# max       54.000000
# Name: highway-mpg, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_4672\1627615137.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["highway-mpg"], shade=True)

# %%
sns.histplot(df["price"],bins=20,kde=True)
plt.title("Automobile_data.csv")
plt.show()     
print(df['price'].describe())
sns.kdeplot(df["price"], shade=True)
plt.title("KDE Plot of price")
plt.show()
# Out:
# count      201.000000
# mean     13207.129353
# std       7947.066342
# min       5118.000000
# 25%       7775.000000
# 50%      10295.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_4672\4077881556.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["price"], shade=True)

# %% [markdown]
# Univariate for Categorical

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["make"])
plt.xticks(rotation=40)
plt.title("make Count")
plt.show()
print(df['make'].describe())
# Out:
# count        201
# unique        22
# top       toyota
# freq          32
# Name: make, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["fuel-type"])
plt.xticks(rotation=40)
plt.title("fuel-type Count")
plt.show()
print(df['fuel-type'].describe())
# Out:
# count     201
# unique      2
# top       gas
# freq      181
# Name: fuel-type, dtype: object

# %%
df["aspiration"].value_counts().plot.pie(autopct="%1.1f%%", colors=["lightblue", "lightgreen"])
plt.title("aspiration Distribution")
plt.ylabel("")
plt.show()
print(df['aspiration'].describe())
# Out:
# count     201
# unique      2
# top       std
# freq      165
# Name: aspiration, dtype: object

# %%
df["num-of-doors"].value_counts().plot.pie(autopct="%1.1f%%", colors=["lightblue", "lightgreen"])
plt.title("num-of-doors Distribution")
plt.ylabel("")
plt.show()
print(df['num-of-doors'].describe())
# Out:
# count      201
# unique       2
# top       four
# freq       115
# Name: num-of-doors, dtype: object

# %%
 df["body-style"].value_counts().plot.pie(autopct="%1.1f%%", colors=["lightblue", "pink"])
 plt.title("body-style Distribution")
 plt.ylabel("")
 plt.show()
print(df['body-style'].describe())
# Out:
# count       201
# unique        5
# top       sedan
# freq         94
# Name: body-style, dtype: object

# %%
 df["drive-wheels"].value_counts().plot.pie(autopct="%1.1f%%", colors=["lightblue", "pink"])
 plt.title("drive-wheels Distribution")
 plt.ylabel("")
 plt.show()
print(df['drive-wheels'].describe())
# Out:
# count     201
# unique      3
# top       fwd
# freq      118
# Name: drive-wheels, dtype: object

# %%
 df["engine-location"].value_counts().plot.pie(autopct="%1.1f%%", colors=["lightblue", "pink"])
 plt.title("engine-location Distribution")
 plt.ylabel("")
 plt.show()
print(df['engine-location'].describe())
# Out:
# count       201
# unique        2
# top       front
# freq        198
# Name: engine-location, dtype: object

# %%
 df["engine-type"].value_counts().plot.pie(autopct="%1.1f%%", colors=["lightblue", "pink"])
 plt.title("engine-type Distribution")
 plt.ylabel("")
 plt.show()
print(df['engine-type'].describe())
# Out:
# count     201
# unique      6
# top       ohc
# freq      145
# Name: engine-type, dtype: object

# %%
 df["num-of-cylinders"].value_counts().plot.pie(autopct="%1.1f%%", colors=["lightblue", "pink"])
 plt.title("num-of-cylinders Distribution")
 plt.ylabel("")
 plt.show()
print(df['num-of-cylinders'].describe())
# Out:
# count      201
# unique       7
# top       four
# freq       157
# Name: num-of-cylinders, dtype: object

# %%
 df["fuel-system"].value_counts().plot.pie(autopct="%1.1f%%", colors=["lightblue", "pink"])
 plt.title("fuel-system Distribution")
 plt.ylabel("")
 plt.show()
print(df['fuel-system'].describe())

plt.figure(figsize=(20,5))
sns.countplot(x=df["fuel-system"])
plt.xticks(rotation=40)
plt.title("fuel-system Count")
plt.show()
# Out:
# count      201
# unique       8
# top       mpfi
# freq        92
# Name: fuel-system, dtype: object

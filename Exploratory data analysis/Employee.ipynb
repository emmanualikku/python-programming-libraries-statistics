# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('Employee.csv')
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 0                             0           0
# 1                             3           1
# 2                             2           0
# 3                             5           1
# 4                             2           1
# ...                         ...         ...
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0
#
# [4653 rows x 9 columns]

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.tail()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.shape
# Out:
# (4653, 9)

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.isnull().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1889

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for columns in df.columns:
    print(df[columns].value_counts())
# Out:
# Education
# Bachelors    1971
# Masters       637
# PHD           156
# Name: count, dtype: int64
# JoiningYear
# 2017    662
# 2015    464
# 2013    396
# 2014    385
# 2016    310
# 2012    308
# 2018    239
# Name: count, dtype: int64
# City
# Bangalore    1171
# Pune          801
# New Delhi     792
# Name: count, dtype: int64
# PaymentTier
# 3    1976
# 2     570
# 1     218
# Name: count, dtype: int64
# Age
# 28    365
# 27    218
# 30    186
# 29    180
# 26    179
# 25    167
# 24    161
# 36    121
# 40    119
# 37    119
# 34    118
# 38    117
# 39    115
# 31    115
# 33    114
# 32    113
# 35    110
# 41     75
# 23     41
# 22     31
# Name: count, dtype: int64
# Gender
# Male      1529
# Female    1235
# Name: count, dtype: int64
# EverBenched
# No     2403
# Yes     361
# Name: count, dtype: int64
# ExperienceInCurrentDomain
# 2    681
# 5    470
# 3    451
# 1    433
# 4    425
# 0    287
# 7      9
# 6      8
# Name: count, dtype: int64
# LeaveOrNot
# 0    1676
# 1    1088
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Education                    object
# JoiningYear                   int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# dtype: object

# %%
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 0                             0           0
# 1                             3           1
# 2                             2           0
# 3                             5           1
# 4                             2           1
# ...                         ...         ...
# 4645                          2           0
# 4647                          2           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
#
# [2764 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["JoiningYear"],bins=20,kde=True)
plt.title("Employee.csv")
plt.show()     
print(df['JoiningYear'].describe())
sns.kdeplot(df["JoiningYear"], shade=True)
plt.title("KDE Plot of JoiningYear")
plt.show()
# Out:
# count    2764.000000
# mean     2015.090449
# std         1.885943
# min      2012.000000
# 25%      2013.000000
# 50%      2015.000000
# 75%      2017.000000
# max      2018.000000
# Name: JoiningYear, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_1480\2701942724.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["JoiningYear"], shade=True)

# %%
sns.histplot(df["PaymentTier"],bins=20,kde=True)
plt.title("Employee.csv")
plt.show()     
print(df['PaymentTier'].describe())
sns.kdeplot(df["PaymentTier"], shade=True)
plt.title("KDE Plot of PaymentTier")
plt.show()
# Out:
# count    2764.000000
# mean        2.636035
# std         0.624001
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         3.000000
# Name: PaymentTier, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_1480\468945869.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["PaymentTier"], shade=True)

# %%
sns.histplot(df["Age"],bins=20,kde=True)
plt.title("Employee.csv")
plt.show()     
print(df['Age'].describe())
sns.kdeplot(df["Age"], shade=True)
plt.title("KDE Plot of Age")
plt.show()
# Out:
# count    2764.000000
# mean       30.952967
# std         5.108872
# min        22.000000
# 25%        27.000000
# 50%        30.000000
# 75%        35.000000
# max        41.000000
# Name: Age, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_1480\4284864570.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["Age"], shade=True)

# %%
sns.histplot(df["ExperienceInCurrentDomain"],bins=20,kde=True)
plt.title("Employee.csv")
plt.show()     
print(df['ExperienceInCurrentDomain'].describe())
sns.kdeplot(df["ExperienceInCurrentDomain"], shade=True)
plt.title("KDE Plot of ExperienceInCurrentDomain")
plt.show()
# Out:
# count    2764.000000
# mean        2.644356
# std         1.610610
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max         7.000000
# Name: ExperienceInCurrentDomain, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_1480\4137576951.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["ExperienceInCurrentDomain"], shade=True)

# %%
sns.histplot(df["LeaveOrNot"],bins=20,kde=True)
plt.title("Employee.csv")
plt.show()     
print(df['LeaveOrNot'].describe())
sns.kdeplot(df["LeaveOrNot"], shade=True)
plt.title("KDE Plot of LeaveOrNot")
plt.show()
# Out:
# count    2764.000000
# mean        0.393632
# std         0.488643
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: LeaveOrNot, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_1480\2392957008.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["LeaveOrNot"], shade=True)

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["Education"])
plt.xticks(rotation=40)
plt.title("Education Count")
plt.show()
print(df['Education'].describe())
# Out:
# count          2764
# unique            3
# top       Bachelors
# freq           1971
# Name: Education, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["City"])
plt.xticks(rotation=40)
plt.title("City Count")
plt.show()
print(df['City'].describe())
# Out:
# count          2764
# unique            3
# top       Bangalore
# freq           1171
# Name: City, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["Gender"])
plt.xticks(rotation=40)
plt.title("Gender Count")
plt.show()
print(df['Gender'].describe())
# Out:
# count     2764
# unique       2
# top       Male
# freq      1529
# Name: Gender, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["EverBenched"])
plt.xticks(rotation=40)
plt.title("EverBenched Count")
plt.show()
print(df['EverBenched'].describe())
# Out:
# count     2764
# unique       2
# top         No
# freq      2403
# Name: EverBenched, dtype: object

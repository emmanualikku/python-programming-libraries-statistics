# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('House_Price.csv')
df
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0     24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1     21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2     34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3     33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4     36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
# ..     ...         ...         ...       ...       ...   ...    ...    ...
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
# ...

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.tail()
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 501   2.76   2.06      19.0       9.67      NO       9.348      12.1792
# 502   2.46   2.14      19.0       9.08     YES       6.612      13.1648
# 503   2.29   1.98      19.0       5.64      NO       5.478      12.1912
# 504   2.40   2.31      19.0       6.48     YES       7.940      15.1760
# 505   2.64   2.42      19.0       7.88     YES      10.280      10.1520
#
#           waterbody  rainfall bus_ter     parks
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    351 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
df.shape
# Out:
# (506, 19)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
df.isnull().sum()
# Out:
# price            0
# crime_rate       0
# resid_area       0
# air_qual         0
# room_num         0
# age              0
# dist1            0
# dist2            0
# dist3            0
# dist4            0
# teachers         0
# poor_prop        0
# airport          0
# n_hos_beds       8
# n_hot_rooms      0
# waterbody      155
# rainfall         0
# bus_ter          0
# parks            0
# dtype: int64

# %%
# df['n_hos_beds'].fillna(df['n_hos_beds'].mean(), inplace=True)
df = df.assign(n_hos_beds=df['n_hos_beds'].fillna(df['n_hos_beds'].mean()))

# %%
# df['waterbody'].fillna(df['waterbody'].mode()[0], inplace=True)
df = df.assign(waterbody=df['waterbody'].fillna(df['waterbody'].mode()[0]))

# %%
df.isnull().sum()
# Out:
# price          0
# crime_rate     0
# resid_area     0
# air_qual       0
# room_num       0
# age            0
# dist1          0
# dist2          0
# dist3          0
# dist4          0
# teachers       0
# poor_prop      0
# airport        0
# n_hos_beds     0
# n_hot_rooms    0
# waterbody      0
# rainfall       0
# bus_ter        0
# parks          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for columns in df.columns:
    print(df[columns].value_counts())
# Out:
# price
# 50.0    16
# 25.0     8
# 23.1     7
# 21.7     7
# 19.4     6
#         ..
# 26.7     1
# 28.1     1
# 48.5     1
# 42.3     1
# 8.1      1
# Name: count, Length: 228, dtype: int64
# crime_rate
# 0.01501     2
# 14.33370    2
# 0.03466     1
# 0.03113     1
# 0.03049     1
#            ..
# 1.51902     1
# 1.83377     1
# 1.46336     1
# 1.27346     1
# 0.04741     1
# Name: count, Length: 504, dtype: int64
# resid_area
# 48.10    132
# 49.58     30
# 38.14     22
# 36.20     18
# 51.89     15
#         ...
# 31.21      1
# 31.38      1
# 33.75      1
# 30.46      1
# 32.31      1
# Name: count, Length: 76, dtype: int64
# air_qual
# 0.538    23
# 0.713    18
# 0.437    17
# 0.871    16
# 0.624    15
#          ..
# 0.394     1
# 0.518     1
# 0.385     1
# 0.389     1
# 0.435     1
# Name: count, Length: 81, dtype: int64
# room_num
# 5.713    3
# 6.167    3
# 6.127    3
# 6.229    3
# 6.405    3
#         ..
# 5.859    1
# 6.416    1
# 5.572    1
# 5.880    1
# 6.976    1
# ...

# %%
df.dtypes
# Out:
# price          float64
# crime_rate     float64
# resid_area     float64
# air_qual       float64
# room_num       float64
# age            float64
# dist1          float64
# dist2          float64
# dist3          float64
# dist4          float64
# teachers       float64
# poor_prop      float64
# airport         object
# n_hos_beds     float64
# n_hot_rooms    float64
# waterbody       object
# rainfall         int64
# bus_ter         object
# parks          float64
# dtype: object

# %%
df
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0     24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1     21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2     34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3     33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4     36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
# ..     ...         ...         ...       ...       ...   ...    ...    ...
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["price"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['price'].describe())
sns.kdeplot(df["price"], shade=True)
plt.title("KDE Plot of price")
plt.show()
# Out:
# count    506.000000
# mean      22.528854
# std        9.182176
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: price, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\4227097624.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["price"], shade=True)

# %%
sns.histplot(df["crime_rate"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['crime_rate'].describe())
sns.kdeplot(df["crime_rate"], shade=True)
plt.title("KDE Plot of crime_rate")
plt.show()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: crime_rate, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\3935900447.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["crime_rate"], shade=True)

# %%
sns.histplot(df["resid_area"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['resid_area'].describe())
sns.kdeplot(df["resid_area"], shade=True)
plt.title("KDE Plot of resid_area")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\3124324555.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["resid_area"], shade=True)
# count    506.000000
# mean      41.136779
# std        6.860353
# min       30.460000
# 25%       35.190000
# 50%       39.690000
# 75%       48.100000
# max       57.740000
# Name: resid_area, dtype: float64

# %%
sns.histplot(df["air_qual"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['air_qual'].describe())
sns.kdeplot(df["air_qual"], shade=True)
plt.title("KDE Plot of air_qual")
plt.show()
# Out:
# count    506.000000
# mean       0.554695
# std        0.115878
# min        0.385000
# 25%        0.449000
# 50%        0.538000
# 75%        0.624000
# max        0.871000
# Name: air_qual, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\66395346.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["air_qual"], shade=True)

# %%
sns.histplot(df["room_num"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['room_num'].describe())
sns.kdeplot(df["room_num"], shade=True)
plt.title("KDE Plot of room_num")
plt.show()
# Out:
# count    506.000000
# mean       6.284634
# std        0.702617
# min        3.561000
# 25%        5.885500
# 50%        6.208500
# 75%        6.623500
# max        8.780000
# Name: room_num, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\1870512811.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["room_num"], shade=True)

# %%
sns.histplot(df["age"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['age'].describe())
sns.kdeplot(df["age"], shade=True)
plt.title("KDE Plot of age")
plt.show()
# Out:
# count    506.000000
# mean      68.574901
# std       28.148861
# min        2.900000
# 25%       45.025000
# 50%       77.500000
# 75%       94.075000
# max      100.000000
# Name: age, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\3198335305.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["age"], shade=True)

# %%
sns.histplot(df["dist1"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['dist1'].describe())
sns.kdeplot(df["dist1"], shade=True)
plt.title("KDE Plot of dist1")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\591013695.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["dist1"], shade=True)
# count    506.000000
# mean       3.971996
# std        2.108532
# min        1.130000
# 25%        2.270000
# 50%        3.385000
# 75%        5.367500
# max       12.320000
# Name: dist1, dtype: float64

# %%
sns.histplot(df["dist2"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['dist2'].describe())
sns.kdeplot(df["dist2"], shade=True)
plt.title("KDE Plot of dist2")
plt.show()
# Out:
# count    506.000000
# mean       3.628775
# std        2.108580
# min        0.920000
# 25%        1.940000
# 50%        3.010000
# 75%        4.992500
# max       11.930000
# Name: dist2, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\2755719015.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["dist2"], shade=True)

# %%
sns.histplot(df["dist3"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['dist3'].describe())
sns.kdeplot(df["dist3"], shade=True)
plt.title("KDE Plot of dist3")
plt.show()
# Out:
# count    506.000000
# mean       3.960672
# std        2.119797
# min        1.150000
# 25%        2.232500
# 50%        3.375000
# 75%        5.407500
# max       12.320000
# Name: dist3, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\3741164610.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["dist3"], shade=True)

# %%
sns.histplot(df["dist4"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['dist4'].describe())
sns.kdeplot(df["dist4"], shade=True)
plt.title("KDE Plot of dist4")
plt.show()
# Out:
# count    506.000000
# mean       3.618972
# std        2.099203
# min        0.730000
# 25%        1.940000
# 50%        3.070000
# 75%        4.985000
# max       11.940000
# Name: dist4, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\1905850208.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["dist4"], shade=True)

# %%
sns.histplot(df["teachers"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['teachers'].describe())
sns.kdeplot(df["teachers"], shade=True)
plt.title("KDE Plot of teachers")
plt.show()
# Out:
# count    506.000000
# mean      21.544466
# std        2.164946
# min       18.000000
# 25%       19.800000
# 50%       20.950000
# 75%       22.600000
# max       27.400000
# Name: teachers, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\638977753.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["teachers"], shade=True)

# %%
sns.histplot(df["poor_prop"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['poor_prop'].describe())
sns.kdeplot(df["poor_prop"], shade=True)
plt.title("KDE Plot of poor_prop")
plt.show()
# Out:
# count    506.000000
# mean      12.653063
# std        7.141062
# min        1.730000
# 25%        6.950000
# 50%       11.360000
# 75%       16.955000
# max       37.970000
# Name: poor_prop, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\1969344708.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["poor_prop"], shade=True)

# %%
sns.histplot(df["n_hos_beds"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['n_hos_beds'].describe())
sns.kdeplot(df["n_hos_beds"], shade=True)
plt.title("KDE Plot of n_hos_beds")
plt.show()
# Out:
# count    506.000000
# mean       7.899767
# std        1.464939
# min        5.268000
# 25%        6.659000
# 50%        7.963000
# 75%        9.076000
# max       10.876000
# Name: n_hos_beds, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\1292711600.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["n_hos_beds"], shade=True)

# %%
sns.histplot(df["n_hot_rooms"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['n_hot_rooms'].describe())
sns.kdeplot(df["n_hot_rooms"], shade=True)
plt.title("KDE Plot of n_hot_rooms")
plt.show()
# Out:
# count    506.000000
# mean      13.041605
# std        5.238957
# min       10.057600
# 25%       11.189800
# 50%       12.720000
# 75%       14.170800
# max      101.120000
# Name: n_hot_rooms, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\2968450624.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["n_hot_rooms"], shade=True)

# %%
sns.histplot(df["rainfall"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['rainfall'].describe())
sns.kdeplot(df["rainfall"], shade=True)
plt.title("KDE Plot of rainfall")
plt.show()
# Out:
# count    506.000000
# mean      39.181818
# std       12.513697
# min        3.000000
# 25%       28.000000
# 50%       39.000000
# 75%       50.000000
# max       60.000000
# Name: rainfall, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\46013789.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["rainfall"], shade=True)

# %%
sns.histplot(df["parks"],bins=20,kde=True)
plt.title("House_Price.csv")
plt.show()     
print(df['parks'].describe())
sns.kdeplot(df["parks"], shade=True)
plt.title("KDE Plot of parks")
plt.show()
# Out:
# count    506.000000
# mean       0.054454
# std        0.010632
# min        0.033292
# 25%        0.046464
# 50%        0.053507
# 75%        0.061397
# max        0.086711
# Name: parks, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_13016\2548357354.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["parks"], shade=True)

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["airport"])
plt.xticks(rotation=40)
plt.title("airport Count")
plt.show()
print(df['airport'].describe())
# Out:
# count     506
# unique      2
# top       YES
# freq      279
# Name: airport, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["waterbody"])
plt.xticks(rotation=40)
plt.title("waterbody Count")
plt.show()
print(df['waterbody'].describe())
# Out:
# count       506
# unique        3
# top       River
# freq        338
# Name: waterbody, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["bus_ter"])
plt.xticks(rotation=40)
plt.title("bus_ter Count")
plt.show()
print(df['bus_ter'].describe())
# Out:
# count     506
# unique      1
# top       YES
# freq      506
# Name: bus_ter, dtype: object

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Medical_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200

# %%
df.shape
# Out:
# (2772, 7)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  2772.000000  2772.000000  2772.000000   2772.000000
# mean     39.109668    30.701349     1.101732  13261.369959
# std      14.081459     6.129449     1.214806  12151.768945
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.220000     0.000000   4687.797000
# 50%      39.000000    30.447500     1.000000   9333.014350
# 75%      51.000000    34.770000     2.000000  16577.779500
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   object
#  2   bmi       2772 non-null   float64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   object
#  5   region    2772 non-null   object
#  6   charges   2772 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 151.7+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1435

# %%
df=df.drop_duplicates()

# %%
df["age"].value_counts()
# Out:
# age
# 18    69
# 19    67
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
df["bmi"].value_counts()
# Out:
# bmi
# 32.30    13
# 28.31     9
# 30.80     8
# 31.35     8
# 28.88     8
#          ..
# 46.20     1
# 23.80     1
# 44.77     1
# 32.12     1
# 30.97     1
# Name: count, Length: 548, dtype: int64

# %%
df["children"].value_counts()
# Out:
# children
# 0    573
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
df["charges"].value_counts()
# Out:
# charges
# 16884.92400    1
# 2117.33885     1
# 2221.56445     1
# 19798.05455    1
# 13063.88300    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: count, Length: 1337, dtype: int64

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["age"],bins=20,kde=True)
plt.title("Medical_insurance.csv")
plt.show()     
print(df['age'].describe())
sns.kdeplot(df["age"], shade=True)
plt.title("KDE Plot of age")
plt.show()
# Out:
# count    1337.000000
# mean       39.222139
# std        14.044333
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_1160\1460184970.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["age"], shade=True)

# %%
sns.histplot(df["bmi"],bins=20,kde=True)
plt.title("Medical_insurance.csv")
plt.show()     
print(df['bmi'].describe())
sns.kdeplot(df["bmi"], shade=True)
plt.title("KDE Plot of bmi")
plt.show()
# Out:
# count    1337.000000
# mean       30.663452
# std         6.100468
# min        15.960000
# 25%        26.290000
# 50%        30.400000
# 75%        34.700000
# max        53.130000
# Name: bmi, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_1160\1514461066.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["bmi"], shade=True)

# %%
sns.histplot(df["children"],bins=20,kde=True)
plt.title("Medical_insurance.csv")
plt.show()     
print(df['children'].describe())
sns.kdeplot(df["children"], shade=True)
plt.title("KDE Plot of children")
plt.show()
# Out:
# count    1337.000000
# mean        1.095737
# std         1.205571
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_1160\3860365906.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["children"], shade=True)

# %%
sns.histplot(df["charges"],bins=20,kde=True)
plt.title("Medical_insurance.csv")
plt.show()     
print(df['charges'].describe())
sns.kdeplot(df["charges"], shade=True)
plt.title("KDE Plot of charges")
plt.show()
# Out:
# count     1337.000000
# mean     13279.121487
# std      12110.359656
# min       1121.873900
# 25%       4746.344000
# 50%       9386.161300
# 75%      16657.717450
# max      63770.428010
# Name: charges, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_1160\427529064.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["charges"], shade=True)

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["sex"])
plt.xticks(rotation=40)
plt.title("sex Count")
plt.show()
print(df['sex'].describe())
# Out:
# count     1337
# unique       2
# top       male
# freq       675
# Name: sex, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["smoker"])
plt.xticks(rotation=40)
plt.title("smoker Count")
plt.show()
print(df['smoker'].describe())
# Out:
# count     1337
# unique       2
# top         no
# freq      1063
# Name: smoker, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["region"])
plt.xticks(rotation=40)
plt.title("region Count")
plt.show()
print(df['region'].describe())
# Out:
# count          1337
# unique            4
# top       southeast
# freq            364
# Name: region, dtype: object
